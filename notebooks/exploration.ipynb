# %% [markdown]
# # Exploration Notebook
#
# This placeholder notebook represents exploratory data analysis (EDA)
# for invoice and transaction anomaly detection.
# In a real workflow, this notebook would include:
# - Data loading
# - Feature engineering
# - IsolationForest / LOF experiments
# - Threshold selection
# - Visualization of anomaly distributions
